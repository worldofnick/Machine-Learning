# %%
import nba_py

# %%
scoreboard = nba_py.Scoreboard(month=5, day=4, year=2017)

# %%
scoreboard.game_header()
# Out:
#          GAME_DATE_EST  GAME_SEQUENCE     GAME_ID  GAME_STATUS_ID  \
# 0  2017-05-04T00:00:00              1  0041600203               3
# 1  2017-05-04T00:00:00              2  0041600222               3
#
#   GAME_STATUS_TEXT         GAMECODE  HOME_TEAM_ID  VISITOR_TEAM_ID SEASON  \
# 0            Final  20170504/BOSWAS    1610612764       1610612738   2016
# 1            Final  20170504/UTAGSW    1610612744       1610612762   2016
#
#    LIVE_PERIOD LIVE_PC_TIME NATL_TV_BROADCASTER_ABBREVIATION  \
# 0            4                                          ESPN
# 1            4                                          ESPN
#
#   LIVE_PERIOD_TIME_BCAST  WH_STATUS
# 0        Q4       - ESPN          1
# 1        Q4       - ESPN          1

# %%
scoreboard.series_standings()
# Out:
#       GAME_ID  HOME_TEAM_ID  VISITOR_TEAM_ID        GAME_DATE_EST  \
# 0  0041600222    1610612744       1610612762  2017-05-04T00:00:00
# 1  0041600203    1610612764       1610612738  2017-05-04T00:00:00
#
#    HOME_TEAM_WINS  HOME_TEAM_LOSSES SERIES_LEADER
# 0               2                 0  Golden State
# 1               1                 2        Boston

# %%
scoreboard.available()
# Out:
#       GAME_ID  PT_AVAILABLE
# 0  0041600203             1
# 1  0041600222             1

# %%
scoreboard.line_score()
# Out:
#          GAME_DATE_EST  GAME_SEQUENCE     GAME_ID     TEAM_ID  \
# 0  2017-05-04T00:00:00              1  0041600203  1610612738
# 1  2017-05-04T00:00:00              1  0041600203  1610612764
# 2  2017-05-04T00:00:00              2  0041600222  1610612762
# 3  2017-05-04T00:00:00              2  0041600222  1610612744
#
#   TEAM_ABBREVIATION TEAM_CITY_NAME TEAM_WINS_LOSSES  PTS_QTR1  PTS_QTR2  \
# 0               BOS         Boston              2-1        17        23
# 1               WAS     Washington              1-2        39        24
# 2               UTA           Utah              0-2        15        32
# 3               GSW   Golden State              2-0        33        27
#
#    PTS_QTR3 ...   PTS_OT8  PTS_OT9  PTS_OT10  PTS  FG_PCT  FT_PCT  FG3_PCT  \
# 0        29 ...         0        0         0   89   0.351   0.758    0.313
# 1        32 ...         0        0         0  116   0.467   0.880    0.320
# ...

# %%
# Lets look at specfic games
from nba_py import game
game_id = '0041600222'

# %%
boxscore = game.BoxscoreSummary(game_id)

# %%
boxscore.inactive_players()
# Out:
#    PLAYER_ID FIRST_NAME LAST_NAME JERSEY_NUM     TEAM_ID     TEAM_CITY  \
# 0     201588     George      Hill        3    1610612762          Utah
# 1     202692       Alec     Burks       10    1610612762          Utah
# 2    1626172      Kevon    Looney        5    1610612744  Golden State
# 3    1627745     Damian     Jones       15    1610612744  Golden State
#
#   TEAM_NAME TEAM_ABBREVIATION
# 0      Jazz               UTA
# 1      Jazz               UTA
# 2  Warriors               GSW
# 3  Warriors               GSW

# %%
boxscore.game_summary()
# Out:
#          GAME_DATE_EST  GAME_SEQUENCE     GAME_ID  GAME_STATUS_ID  \
# 0  2017-05-04T00:00:00              2  0041600222               3
#
#   GAME_STATUS_TEXT         GAMECODE  HOME_TEAM_ID  VISITOR_TEAM_ID SEASON  \
# 0            Final  20170504/UTAGSW    1610612744       1610612762   2016
#
#    LIVE_PERIOD LIVE_PC_TIME NATL_TV_BROADCASTER_ABBREVIATION  \
# 0            4                                          ESPN
#
#   LIVE_PERIOD_TIME_BCAST  WH_STATUS
# 0        Q4       - ESPN          1

# %%
boxscore.game_info()
# Out:
#                GAME_DATE  ATTENDANCE GAME_TIME
# 0  THURSDAY, MAY 4, 2017       19596      2:22

# %%
boxscore.other_stats()
# Out:
#   LEAGUE_ID     TEAM_ID TEAM_ABBREVIATION     TEAM_CITY  PTS_PAINT  \
# 0        00  1610612744               GSW  Golden State         42
# 1        00  1610612762               UTA          Utah         42
#
#    PTS_2ND_CHANCE  PTS_FB  LARGEST_LEAD  LEAD_CHANGES  TIMES_TIED  \
# 0              15      19            20             0           0
# 1               6      18             0             0           0
#
#    TEAM_TURNOVERS  TOTAL_TURNOVERS  TEAM_REBOUNDS  PTS_OFF_TO
# 0               0               17              3          22
# 1               1               15              7          24

# %%
boxscore.last_meeting()
# Out:
#       GAME_ID LAST_GAME_ID   LAST_GAME_DATE_EST  LAST_GAME_HOME_TEAM_ID  \
# 0  0041600222   0041600221  2017-05-02T00:00:00              1610612744
#
#   LAST_GAME_HOME_TEAM_CITY LAST_GAME_HOME_TEAM_NAME  \
# 0             Golden State                 Warriors
#
#   LAST_GAME_HOME_TEAM_ABBREVIATION  LAST_GAME_HOME_TEAM_POINTS  \
# 0                              GSW                         106
#
#    LAST_GAME_VISITOR_TEAM_ID LAST_GAME_VISITOR_TEAM_CITY  \
# 0                 1610612762                        Utah
#
#   LAST_GAME_VISITOR_TEAM_NAME LAST_GAME_VISITOR_TEAM_CITY1  \
# 0                        Jazz                          UTA
#
#    LAST_GAME_VISITOR_TEAM_POINTS
# 0                             94

# %%
boxscore.season_series()
# Out:
#       GAME_ID  HOME_TEAM_ID  VISITOR_TEAM_ID        GAME_DATE_EST  \
# 0  0041600222    1610612744       1610612762  2017-05-04T00:00:00
#
#    HOME_TEAM_WINS  HOME_TEAM_LOSSES SERIES_LEADER
# 0               2                 0  Golden State

# %%
boxscore.officials()
# Out:
#    OFFICIAL_ID FIRST_NAME LAST_NAME JERSEY_NUM
# 0         1195    Derrick  Stafford       9
# 1         2002    Derrick   Collins       11
# 2         2534       Zach     Zarba       15

# %%
boxscore_scoring = game.BoxscoreScoring(game_id)

# %%
boxscore_scoring
# Out:
#        GAME_ID     TEAM_ID TEAM_ABBREVIATION     TEAM_CITY  PLAYER_ID  \
# 0   0041600222  1610612762               UTA          Utah     202330
# 1   0041600222  1610612762               UTA          Utah       2207
# 2   0041600222  1610612762               UTA          Utah     203497
# 3   0041600222  1610612762               UTA          Utah     204060
# 4   0041600222  1610612762               UTA          Utah     202714
# 5   0041600222  1610612762               UTA          Utah     203918
# 6   0041600222  1610612762               UTA          Utah     203526
# 7   0041600222  1610612762               UTA          Utah       2564
# 8   0041600222  1610612762               UTA          Utah     202324
# 9   0041600222  1610612762               UTA          Utah     203957
# 10  0041600222  1610612762               UTA          Utah    1627762
# 11  0041600222  1610612762               UTA          Utah    1626168
# ...

# %%
boxscore_usage = game.BoxscoreUsage(game_id)

# %%
boxscore_usage
# Out:
# <nba_py.game.BoxscoreUsage instance at 0x111479098>

# %%
boxscore_usage.sql_players_usage()
# Out:
#        GAME_ID     TEAM_ID TEAM_ABBREVIATION     TEAM_CITY  PLAYER_ID  \
# 0   0041600222  1610612762               UTA          Utah     202330
# 1   0041600222  1610612762               UTA          Utah       2207
# 2   0041600222  1610612762               UTA          Utah     203497
# 3   0041600222  1610612762               UTA          Utah     204060
# 4   0041600222  1610612762               UTA          Utah     202714
# 5   0041600222  1610612762               UTA          Utah     203918
# 6   0041600222  1610612762               UTA          Utah     203526
# 7   0041600222  1610612762               UTA          Utah       2564
# 8   0041600222  1610612762               UTA          Utah     202324
# 9   0041600222  1610612762               UTA          Utah     203957
# 10  0041600222  1610612762               UTA          Utah    1627762
# 11  0041600222  1610612762               UTA          Utah    1626168
# ...

# %%
boxscore_misc = game.BoxscoreMisc(game_id)

# %%
boxscore_misc
# Out:
# <nba_py.game.BoxscoreMisc instance at 0x111530098>

# %%
boxscore_misc.sql_players_misc()
# Out:
#        GAME_ID     TEAM_ID TEAM_ABBREVIATION     TEAM_CITY  PLAYER_ID  \
# 0   0041600222  1610612762               UTA          Utah     202330
# 1   0041600222  1610612762               UTA          Utah       2207
# 2   0041600222  1610612762               UTA          Utah     203497
# 3   0041600222  1610612762               UTA          Utah     204060
# 4   0041600222  1610612762               UTA          Utah     202714
# 5   0041600222  1610612762               UTA          Utah     203918
# 6   0041600222  1610612762               UTA          Utah     203526
# 7   0041600222  1610612762               UTA          Utah       2564
# 8   0041600222  1610612762               UTA          Utah     202324
# 9   0041600222  1610612762               UTA          Utah     203957
# 10  0041600222  1610612762               UTA          Utah    1627762
# 11  0041600222  1610612762               UTA          Utah    1626168
# ...

# %%
boxscore_misc.sql_team_misc()
# Out:
#       GAME_ID     TEAM_ID TEAM_NAME TEAM_ABBREVIATION     TEAM_CITY     MIN  \
# 0  0041600222  1610612762      Jazz               UTA          Utah  240:00
# 1  0041600222  1610612744  Warriors               GSW  Golden State  240:00
#
#    PTS_OFF_TOV  PTS_2ND_CHANCE  PTS_FB  PTS_PAINT  OPP_PTS_OFF_TOV  \
# 0         22.0             6.0    18.0       42.0             24.0
# 1         24.0            15.0    19.0       42.0             22.0
#
#    OPP_PTS_2ND_CHANCE  OPP_PTS_FB  OPP_PTS_PAINT  BLK  BLKA  PF  PFD
# 0                15.0        19.0           42.0    2     4  23   20
# 1                 6.0        18.0           42.0    4     2  20   23

# %%
boxscore_advacned = game.BoxscoreAdvanced(game_id)

# %%
boxscore_advacned
# Out:
# <nba_py.game.BoxscoreAdvanced instance at 0x11152d3f8>

# %%
boxscore_advacned.sql_players_advanced()
# Out:
#        GAME_ID     TEAM_ID TEAM_ABBREVIATION     TEAM_CITY  PLAYER_ID  \
# 0   0041600222  1610612762               UTA          Utah     202330
# 1   0041600222  1610612762               UTA          Utah       2207
# 2   0041600222  1610612762               UTA          Utah     203497
# 3   0041600222  1610612762               UTA          Utah     204060
# 4   0041600222  1610612762               UTA          Utah     202714
# 5   0041600222  1610612762               UTA          Utah     203918
# 6   0041600222  1610612762               UTA          Utah     203526
# 7   0041600222  1610612762               UTA          Utah       2564
# 8   0041600222  1610612762               UTA          Utah     202324
# 9   0041600222  1610612762               UTA          Utah     203957
# 10  0041600222  1610612762               UTA          Utah    1627762
# 11  0041600222  1610612762               UTA          Utah    1626168
# ...

# %%
boxscore_advacned.sql_team_advanced()
# Out:
#       GAME_ID     TEAM_ID TEAM_NAME TEAM_ABBREVIATION     TEAM_CITY     MIN  \
# 0  0041600222  1610612762      Jazz               UTA          Utah  240:00
# 1  0041600222  1610612744  Warriors               GSW  Golden State  240:00
#
#    OFF_RATING  DEF_RATING  NET_RATING  AST_PCT  ...    AST_RATIO  OREB_PCT  \
# 0       101.2       113.0       -11.8    0.500  ...         15.0     0.116
# 1       113.0       101.2        11.8    0.786  ...         22.9     0.209
#
#    DREB_PCT  REB_PCT  TM_TOV_PCT  EFG_PCT  TS_PCT  USG_PCT   PACE    PIE
# 0     0.791    0.453      14.591    0.524   0.560    0.198  102.3  0.403
# 1     0.884    0.547      16.699    0.576   0.613    0.200  102.3  0.597
#
# [2 rows x 21 columns]

# %%
boxscore_fourfactors = game.BoxscoreFourFactors(game_id)

# %%
boxscore_fourfactors
# Out:
# <nba_py.game.BoxscoreFourFactors instance at 0x11147c998>

# %%
boxscore_fourfactors.sql_team_four_factors()
# Out:
#       GAME_ID     TEAM_ID TEAM_NAME TEAM_ABBREVIATION     TEAM_CITY     MIN  \
# 0  0041600222  1610612762      Jazz               UTA          Utah  240:00
# 1  0041600222  1610612744  Warriors               GSW  Golden State  240:00
#
#    EFG_PCT  FTA_RATE  TM_TOV_PCT  OREB_PCT  OPP_EFG_PCT  OPP_FTA_RATE  \
# 0    0.524     0.238       0.146     0.116        0.576         0.235
# 1    0.576     0.235       0.167     0.209        0.524         0.238
#
#    OPP_TOV_PCT  OPP_OREB_PCT
# 0        0.167         0.209
# 1        0.146         0.116

# %%
boxscore_playbyplay = game.PlayByPlay(game_id)

# %%
boxscore_playbyplay
# Out:
# <nba_py.game.PlayByPlay instance at 0x11152d128>

# %%
boxscore_playbyplay.info()
# Out:
#         GAME_ID  EVENTNUM  EVENTMSGTYPE  EVENTMSGACTIONTYPE  PERIOD  \
# 0    0041600222         0            12                   0       1
# 1    0041600222         1            10                   0       1
# 2    0041600222         2             1                  63       1
# 3    0041600222         3             6                  27       1
# 4    0041600222         4             2                  52       1
# 5    0041600222         5             4                   0       1
# 6    0041600222         6             1                  79       1
# 7    0041600222         7             1                   1       1
# 8    0041600222         8             2                   1       1
# 9    0041600222         9             4                   0       1
# 10   0041600222        10             1                  63       1
# 11   0041600222        11             5                   1       1
# 12   0041600222        12             1                  44       1
# ...

# %%
boxscore_playbyplay.available_video()
# Out:
#    VIDEO_AVAILABLE_FLAG
# 0                     1

# %%
boxscore_hustlestats = game.HustleStats(game_id)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-68-dcc64d1d9f95> in <module>()
# ----> 1 boxscore_hustlestats = game.HustleStats(game_id)
#
# AttributeError: 'module' object has no attribute 'HustleStats'
